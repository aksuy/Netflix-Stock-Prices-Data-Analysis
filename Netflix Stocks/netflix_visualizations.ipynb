# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
netflix_stocks = pd.read_csv('NFLX.csv')
print(netflix_stocks.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-01  124.959999  143.460007  124.309998  140.710007  140.710007
# 1  2017-02-01  141.199997  145.949997  139.050003  142.130005  142.130005
# 2  2017-03-01  142.839996  148.289993  138.259995  147.809998  147.809998
# 3  2017-04-01  146.699997  153.520004  138.660004  152.199997  152.199997
# 4  2017-05-01  151.910004  164.750000  151.610001  163.070007  163.070007
#
#       Volume
# 0  181772200
# 1   91432000
# 2  110692700
# 3  149769200
# 4  116795800

# %%
dowjones_stocks = pd.read_csv('DJI.csv')
print(dowjones_stocks.head())
# Out:
#          Date          Open          High           Low         Close  \
# 0  2017-01-01  19872.859375  20125.580078  19677.939453  19864.089844
# 1  2017-02-01  19923.810547  20851.330078  19831.089844  20812.240234
# 2  2017-03-01  20957.289063  21169.109375  20412.800781  20663.220703
# 3  2017-04-01  20665.169922  21070.900391  20379.550781  20940.509766
# 4  2017-05-01  20962.730469  21112.320313  20553.449219  21008.650391
#
#       Adj Close      Volume
# 0  19864.089844  6482450000
# 1  20812.240234  6185580000
# 2  20663.220703  6941970000
# 3  20940.509766  5392630000
# 4  21008.650391  6613570000

# %%
netflix_stocks_quarterly = pd.read_csv('NFLX_daily_by_quarter.csv')
print(netflix_stocks_quarterly.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-03  124.959999  128.190002  124.309998  127.489998  127.489998
# 1  2017-01-04  127.489998  130.169998  126.550003  129.410004  129.410004
# 2  2017-01-05  129.220001  132.750000  128.899994  131.809998  131.809998
# 3  2017-01-06  132.080002  133.880005  129.809998  131.070007  131.070007
# 4  2017-01-09  131.479996  131.990005  129.889999  130.949997  130.949997
#
#      Volume Quarter
# 0   9437900      Q1
# 1   7843600      Q1
# 2  10185500      Q1
# 3  10657900      Q1
# 4   5766900      Q1

# %%
'''Earliest date for NFLX is 1st Jan 2017, end date is not mentioned but logically it has to be 1st December 2017.
Values are montlhy.
Earliest date for DJI is 1st Jan 2017, end date is not mentioned but logically it has to be 1st December 2017.
Values are montlhy.
Earliest date for NFLX_daily_by_quarter is 3rd Jan 2017 and end date is not mentioned.
'''

# %%
# Data is represented in represented in the form of month/day/year
# Files are in the form of cvv and one is in the form of jupyter notebooks
# Data in netflix is monthly and that of stocks_quarterly is daily, but Stocks_quarterly have an extra column named Quarterly.

# %%
print(netflix_stocks.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-01  124.959999  143.460007  124.309998  140.710007  140.710007
# 1  2017-02-01  141.199997  145.949997  139.050003  142.130005  142.130005
# 2  2017-03-01  142.839996  148.289993  138.259995  147.809998  147.809998
# 3  2017-04-01  146.699997  153.520004  138.660004  152.199997  152.199997
# 4  2017-05-01  151.910004  164.750000  151.610001  163.070007  163.070007
#
#       Volume
# 0  181772200
# 1   91432000
# 2  110692700
# 3  149769200
# 4  116795800

# %%
netflix_stocks.rename({'Adj Close': 'Price'},axis=1, inplace=True)
dowjones_stocks.rename({'Adj Close': 'Price'},axis=1, inplace=True)
netflix_stocks_quarterly.rename({'Adj Close': 'Price'},axis=1, inplace=True)

# %% [markdown]
# Run `netflix_stocks.head()` again to check your column name has changed.

# %%
print(netflix_stocks.head())
# Out:
#          Date        Open        High         Low       Close       Price  \
# 0  2017-01-01  124.959999  143.460007  124.309998  140.710007  140.710007
# 1  2017-02-01  141.199997  145.949997  139.050003  142.130005  142.130005
# 2  2017-03-01  142.839996  148.289993  138.259995  147.809998  147.809998
# 3  2017-04-01  146.699997  153.520004  138.660004  152.199997  152.199997
# 4  2017-05-01  151.910004  164.750000  151.610001  163.070007  163.070007
#
#       Volume
# 0  181772200
# 1   91432000
# 2  110692700
# 3  149769200
# 4  116795800

# %%
print(netflix_stocks_quarterly.head())
print(dowjones_stocks.head())
# Out:
#          Date        Open        High         Low       Close       Price  \
# 0  2017-01-03  124.959999  128.190002  124.309998  127.489998  127.489998
# 1  2017-01-04  127.489998  130.169998  126.550003  129.410004  129.410004
# 2  2017-01-05  129.220001  132.750000  128.899994  131.809998  131.809998
# 3  2017-01-06  132.080002  133.880005  129.809998  131.070007  131.070007
# 4  2017-01-09  131.479996  131.990005  129.889999  130.949997  130.949997
#
#      Volume Quarter
# 0   9437900      Q1
# 1   7843600      Q1
# 2  10185500      Q1
# 3  10657900      Q1
# 4   5766900      Q1
#          Date          Open          High           Low         Close  \
# 0  2017-01-01  19872.859375  20125.580078  19677.939453  19864.089844
# 1  2017-02-01  19923.810547  20851.330078  19831.089844  20812.240234
# 2  2017-03-01  20957.289063  21169.109375  20412.800781  20663.220703
# 3  2017-04-01  20665.169922  21070.900391  20379.550781  20940.509766
# ...

# %%
ax = sns.violinplot()
sns.violinplot(data = netflix_stocks_quarterly, x = 'Quarter', y= 'Price')
ax.set_title('Distribution of 2017 Netflix Stock Prices by Quarter')
ax.set_xlabel('Business Quarters in 2017')
ax.set_ylabel('Closing Stock Price')
# Out:
# Text(0, 0.5, 'Closing Stock Price')

# %%
# The mean closing stock price increase gradually each Quarter.
# Lowest stock price was recorded in Q1 which was around 120 and highest was in Q4 which was just above 200.

# %%
x_positions = [1, 2, 3, 4]
chart_labels = ["1Q2017","2Q2017","3Q2017","4Q2017"]
earnings_actual =[.4, .15,.29,.41]
earnings_estimate = [.37,.15,.32,.41 ]
plt.scatter(x_positions, earnings_actual, color = 'red', alpha = 0.3)

plt.scatter(x_positions, earnings_estimate, color = 'blue', alpha= 0.3)

# %%
# The metrics below are in billions of dollars
revenue_by_quarter = [2.79, 2.98,3.29,3.7]
earnings_by_quarter = [.0656,.12959,.18552,.29012]
quarter_labels = ["2Q2017","3Q2017","4Q2017", "1Q2018"]

# Revenue
n = 1  # This is our first dataset (out of 2)
t = 2 # Number of dataset
d = 4 # Number of sets of bars
w = 0.8 # Width of each bar
bars1_x = [t*element + w*n for element
             in range(d)]



# Earnings
n = 2  # This is our second dataset (out of 2)
t = 2 # Number of dataset
d = 4 # Number of sets of bars
w = 0.8 # Width of each bar
bars2_x = [t*element + w*n for element
             in range(d)]



plt.bar(bars1_x,revenue_by_quarter)
plt.bar(bars2_x,earnings_by_quarter)

middle_x = [ (a + b) / 2.0 for a, b in zip(bars1_x, bars2_x)]
labels = ["Revenue", "Earnings"]
plt.legend(['Revenue','Earnings'])
plt.title('Revenue X Earnings')
plt.xticks(middle_x, quarter_labels)
#plt.bar(bars1_x,revenue_by_quarter)
#plt.bar(bars2_x,earnings_by_quarter)
# Out:
# ([<matplotlib.axis.XTick at 0x248597a5be0>,
# ...
#  [Text(1.2000000000000002, 0, '2Q2017'),
#   Text(3.2, 0, '3Q2017'),
#   Text(5.199999999999999, 0, '4Q2017'),
#   Text(7.199999999999999, 0, '1Q2018')])

# %%
#Revenue follows the pattern of gradually incerasing each quarter. Postive Growth is seen.
#Earnings follows the same pattern as that of the Revenue/ Growth heer again is positive.
# For the second quarter of 2017 earning is 2.3% of revenue. For the third quarter of 2017 earning is 4.3% of revenue.
#For final quarter of 2017 earning is 5.6% of the revenue. For first quqrter of 2018, it is 7.8%

#There is gradual increase in percentage of return wrt to revenue.

# %%
# Left plot Netflix
ax1 = plt.subplot(1, 2, 1)
plt.plot(netflix_stocks['Date'],netflix_stocks['Price'])
ax1.set_title('Netflix')
ax1.set_xlabel('Date')
ax1.set_ylabel('Stock Price')
plt.xticks(rotation=90)






# Right plot Dow Jones
ax2 = plt.subplot(1, 2, 2)
plt.plot(dowjones_stocks['Date'], dowjones_stocks['Price'])
ax2.set_title('Dow Jones')
ax2.set_xlabel('Date')
ax2.set_ylabel('Stock Price')
plt.subplots_adjust(wspace = 0.5)
plt.xticks(rotation=90)
plt.show()

# %%
plt.savefig('NetflixXDJI.png')

# %%
'''
>DJI stocks were relatively more exponential with a very little period where it was either down or
 stagnant.
>Compared to DJI, netflix was a little less exponential it had 3 downgrowth as compare to dji.
>Both the stocks show postive growth in the year 2017.
>Netflix' stocks are more volatile as they faced 3 downgrowths.
>DJI has more stock price which is obviouis as dji is index
 of 30 prominent companies listed on stock exchanges in the United States.
>And netflix itself is an independent entity.
>Netflix started at 140 USD and by the end was around 190 which showed around 35% increase.
>DJI started up at around 20000 and ended up at around 25000 which is around 25% increase.

>AS we can see Netflix has more increase in percentage as that of DJI.'''
